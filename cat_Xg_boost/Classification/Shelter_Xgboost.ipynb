# %%
from google.colab import drive
from os.path import join

ROOT = '/content/drive'     # default for the drive
PROJ = 'My Drive/node-master'       # path to your project on Drive

GIT_USERNAME = "sgsyang" # replace with yours
#GIT_TOKEN = "XXX"           # definitely replace with yours
#GIT_REPOSITORY = "yyy"      # ...nah


drive.mount(ROOT)           # we mount the drive at /content/drive

PROJECT_PATH = join(ROOT, PROJ)
# !mkdir "{PROJECT_PATH}"    # in case we haven't created it already   

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git"
GIT_PATH = "https://github.com/sgsyang/node.git"

# !mkdir ./temp
# !git clone "{GIT_PATH}"
# !mv ./temp/* "{PROJECT_PATH}"
# !rm -rf ./temp
# !rsync -aP --exclude=data/ "{PROJECT_PATH}"/*  ./
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/node-master’: File exists
# Cloning into 'node'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 19 (delta 0), reused 19 (delta 0), pack-reused 0
# Unpacking objects: 100% (19/19), done.
# mv: cannot stat './temp/*': No such file or directory
# sending incremental file list
# README.md
#           1,555 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=35/36)
# requirements.txt
#             209 100%    0.27kB/s    0:00:00 (xfr#2, to-chk=34/36)
# images/
# images/densetree.png
#         140,768 100%  103.00MB/s    0:00:00 (xfr#3, to-chk=30/36)
# lib/
# lib/__init__.py
#             128 100%    0.19kB/s    0:00:00 (xfr#4, to-chk=29/36)
# lib/arch.py
#           1,642 100%    1.18kB/s    0:00:01 (xfr#5, to-chk=28/36)
# lib/data.py
#          28,710 100%    0.00kB/s    0:00:00 (xfr#6, to-chk=27/36)
# lib/nn_utils.py
#           7,443 100%   13.31kB/s    0:00:00 (xfr#7, to-chk=26/36)
# lib/odst.py
#           8,041 100%    6.77kB/s    0:00:01 (xfr#8, to-chk=25/36)
# lib/trainer.py
#           7,596 100%    0.00kB/s    0:00:00 (xfr#9, to-chk=24/36)
# lib/utils.py
#           4,132 100%    7.10kB/s    0:00:00 (xfr#10, to-chk=23/36)
# notebooks/
# notebooks/Epsilon_Catboost.ipynb
#         160,361 100%  118.64kB/s    0:00:01 (xfr#11, to-chk=22/36)
# notebooks/Epsilon_Catboost.ipynb（副本）
#          33,789 100%   43.36kB/s    0:00:00 (xfr#12, to-chk=21/36)
# notebooks/Classification/
# notebooks/Classification/Adult_Catoost.ipynb
#         487,296 100%  216.74MB/s    0:00:00 (xfr#13, to-chk=17/36)
# notebooks/Classification/Adult_Xgboost.ipynb
#          61,109 100%   85.50kB/s    0:00:00 (xfr#14, to-chk=16/36)
# notebooks/Classification/Click_Catoost.ipynb
#         456,805 100%  305.34kB/s    0:00:01 (xfr#15, to-chk=15/36)
# notebooks/Classification/Click_Xgboost.ipynb
#          35,341 100%   42.35kB/s    0:00:00 (xfr#16, to-chk=14/36)
# notebooks/Classification/Shelter_Catoost.ipynb
#          63,591 100%   29.40MB/s    0:00:00 (xfr#17, to-chk=13/36)
# notebooks/Classification/Shelter_Xgboost.ipynb
#          52,978 100%   55.27kB/s    0:00:00 (xfr#18, to-chk=12/36)
# notebooks/Classification/Others/
# notebooks/Classification/Others/Higgs_Catoost.ipynb
#         457,455 100%  202.51MB/s    0:00:00 (xfr#19, to-chk=10/36)
# notebooks/Classification/Others/Higgs_Xgboost.ipynb
#          37,258 100%   45.20kB/s    0:00:00 (xfr#20, to-chk=9/36)
# notebooks/Origin/
# notebooks/Origin/epsilon_node_multigpu.ipynb
#          32,441 100%    0.00kB/s    0:00:00 (xfr#21, to-chk=8/36)
# notebooks/Origin/year_node_8layers.ipynb
#          50,804 100%   69.39kB/s    0:00:00 (xfr#22, to-chk=7/36)
# notebooks/Origin/year_node_shallow.ipynb
#          45,433 100%   34.42kB/s    0:00:01 (xfr#23, to-chk=6/36)
# notebooks/Regression/
# notebooks/Regression/Microsoft_catboost.ipynb
#         310,543 100%  402.74kB/s    0:00:00 (xfr#24, to-chk=5/36)
# notebooks/Regression/Miscrosoft_XgtBoost.ipynb
#          37,628 100%   24.86kB/s    0:00:01 (xfr#25, to-chk=4/36)
# notebooks/Regression/Yahoo_CatBoost.ipynb
#         520,119 100%  647.04kB/s    0:00:00 (xfr#26, to-chk=3/36)
# notebooks/Regression/Yahoo_XgtBoost.ipynb
#          35,954 100%    3.04MB/s    0:00:00 (xfr#27, to-chk=2/36)
# notebooks/Regression/Year_CatBoost.ipynb
#         444,116 100%  478.71kB/s    0:00:00 (xfr#28, to-chk=1/36)
# notebooks/Regression/Year_XgtBoost.ipynb
#          48,503 100%   15.01MB/s    0:00:00 (xfr#29, to-chk=0/36)

# %%
# !pip install xgboost
# !pip install category_encoders
# !pip install tensorboardX
# !pip install qhoptim

# %load_ext autoreload
# %autoreload 2
# %env CUDA_VISIBLE_DEVICES=0,1
import os, sys
import time
sys.path.insert(0, '..')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import lib
import torch, torch.nn as nn
import torch.nn.functional as F
# from qhoptim.pyt import QHAdam


# DATASETS = {
#     'A9A': fetch_A9A,
#     'EPSILON': fetch_EPSILON,
#     'PROTEIN': fetch_PROTEIN,
#     'YEAR': fetch_YEAR,
#     'HIGGS': fetch_HIGGS,
#     'MICROSOFT': fetch_MICROSOFT,
#     'YAHOO': fetch_YAHOO,
#     'CLICK': fetch_CLICK,
# }



device = 'cuda' if torch.cuda.is_available() else 'cpu'

experiment_name = 'Shelter_Xgboost'
experiment_name = '{}_{}.{:0>2d}.{:0>2d}_{:0>2d}:{:0>2d}'.format(experiment_name, *time.gmtime()[:5])
print("experiment:", experiment_name)
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.6/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from xgboost) (1.18.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from xgboost) (1.4.1)
# Collecting category_encoders
#   Downloading https://files.pythonhosted.org/packages/44/57/fcef41c248701ee62e8325026b90c432adea35555cbc870aff9cfba23727/category_encoders-2.2.2-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 1.9MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.0.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.18.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->category_encoders) (0.15.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5.1->category_encoders) (1.12.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/35/f1/5843425495765c8c2dd0784a851a93ef204d314fc87bcc2bbb9f662a3ad1/tensorboardX-2.0-py2.py3-none-any.whl (195kB)
#      |████████████████████████████████| 204kB 2.8MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (46.3.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.0
# env: CUDA_VISIBLE_DEVICES=0,1
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# experiment: Shelter_Xgboost_2020.05.27_17:19

# %%
torch.cuda.get_device_name(device)
# Out:
# 'Tesla P100-PCIE-16GB'

# %%
data = lib.Dataset("SHELTER", random_state=1337, quantile_transform=True, quantile_noise=1e-3)

num_features = data.X_train.shape[1]
num_classes = len(set(data.y_train))

print(num_classes )
# Out:
# Downloading 15fHBRQM5ztc1LUiAhPiYTOggi5lyw4C- into ./data/SHELTER/train.zip... Done.
# Unzipping...Done.
# Downloading 1I0QqJOUM_lhAdcUZnmninHEqi68nMeju into ./data/SHELTER/test.zip... Done.
# Unzipping...Done.
# 5

# %% [markdown]
# ##Default Parameters

# %%
import numpy as np
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score



# read the data
data = lib.Dataset("SHELTER", random_state=1337, quantile_transform=True, quantile_noise=1e-3)

num_features = data.X_train.shape[1]
num_classes = len(set(data.y_train))


model = XGBClassifier(objective = 'multi:softmax',num_class = num_classes,tree_method='gpu_hist')
# model = XGBClassifier(tree_method='gpu_hist')

model.fit(data.X_train, data.y_train)

pred = model.predict(data.X_test)
# pred = check_numpy(pred)
# pred = np.argmax(logits, axis=1)

accuracy = accuracy_score(data.y_test, pred)
# The classifation Error
# Dataset: Shelter

print('The Error:',1-accuracy)
# Out:
# The Error: 0.35911312849162014
# 5

# %% [markdown]
# ##Tuned Parameters

# %%
# !pip install hyperopt
import xgboost as xgb
import hyperopt
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.41.1)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
#AUTOMATE 
import math
import numpy as np
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

space={'eta': hp.loguniform('eta',np.exp(-7) ,1),
       'max_depth': hp.quniform("max_depth", 2,10,1),
       'subsample': hp.uniform('subsample', 0.5, 1),
       'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
       'colsample_bylevel' : hp.uniform('colsample_bylevel', 0.5,1),
       'min_child_weight' : hp.loguniform('min_child_weight', np.exp(-16),np.exp(4)),
       'alpha' : hp.choice('alpha', [0,hp.loguniform('a',np.exp(-16),np.exp(2))]),
       'lambda': hp.choice('lambda',[ 0,hp.loguniform('l',np.exp(-16),np.exp(2))]),
       'gamma': hp.choice ('gamma', [0,hp.loguniform('g',np.exp(-16),np.exp(2))]) 
    }

def my_tuning(space):
    reg= XGBClassifier( eta = space['eta'],max_depth = int(space['max_depth']), subsample=space['subsample'],
                         gamma = space['gamma'],reg_alpha = space['alpha'],reg_lambda = space['lambda'],
                         min_child_weight=space['min_child_weight'],
                         colsample_bytree=space['colsample_bytree'],
                         colsample_bylevel = space['colsample_bylevel'],
                         objective = 'multi:softmax',num_class = num_classes,
                         tree_method='gpu_hist')
    
    reg.fit(data.X_train, data.y_train)

    pred = reg.predict(data.X_test)

    accuracy = accuracy_score(data.y_test, pred)
    # The classifation Error
    # Dataset: Shelter 
  
    error = 1-accuracy
    print('The Error:',error)
    if error == 0.0:
      error+=1

    
    #change the metric if you like
    return {'loss':error, 'status': STATUS_OK }



score_results = [] 
key_results = []

random_state = [1337, 133,13, 1, 602, 295, 970, 2000, 3000, 10000]
# random_state = [1337]
for i in random_state:
  data = lib.Dataset("SHELTER", random_state=i, quantile_transform=True, quantile_noise=1e-3)
  num_features = data.X_train.shape[1]
  num_classes = len(set(data.y_train))

  print(f'The dataset with random state {i} is used')

  trials = Trials()
  best = fmin(fn=my_tuning,
            space=space,
            algo=tpe.suggest,
            max_evals=50,
            trials=trials)
  # print('Best parameters',best)
  tuned_loss = trials.best_trial['result']['loss']
  print('Best Loss',tuned_loss)
  final = tuned_loss
  print('FINAL Error:',final)
  score_results.append(final)
  key_results.append(i)


import pprint
Result= dict(zip(key_results,score_results))

print('----')
pprint.pprint(Result, width=1)

mean = sum(score_results) / len(score_results)
print('Mean:',mean)
print('Max:',max(score_results))
print('Min:',min(score_results))
print('Distance to max',max(score_results)-mean)
print('Distance to min:',min(score_results)-mean)
# Out:
# The dataset with random state 1337 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3669692737430168
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.39315642458100564
# The Error:
# 0.36915153631284914
# The Error:
# 0.38957751396648044
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.35911312849162014
# The Error:
# 0.0
# The Error:
# 0.33990921787709494
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3380761173184358
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.36792946927374304
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.36836592178770955
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.34881284916201116
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2939944134078212
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.4157646648044693
# 100%|██████████| 50/50 [00:51<00:00,  1.03s/it, best loss: 0.25776885474860334]
# Best Loss 0.25776885474860334
# FINAL Error: 0.25776885474860334
# The dataset with random state 133 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.31590432960893855
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.38722067039106145
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3990921787709497
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.35640712290502796
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.31153980446927376
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.299231843575419
# The Error:
# 0.0
# The Error:
# 0.3578910614525139
# The Error:
# 0.0
# The Error:
# 0.30272346368715086
# The Error:
# 0.3578910614525139
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3269029329608939
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2976606145251397
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3036836592178771
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.30185055865921784
# The Error:
# 0.2912011173184358
# The Error:
# 0.0
# The Error:
# 0.416288407821229
# 100%|██████████| 50/50 [00:52<00:00,  1.04s/it, best loss: 0.25776885474860334]
# Best Loss 0.25776885474860334
# FINAL Error: 0.25776885474860334
# The dataset with random state 13 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3113652234636871
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.35762918994413406
# The Error:
# 0.39725907821229045
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.32236382681564246
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2644902234636871
# The Error:
# 0.2976606145251397
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.325768156424581
# The Error:
# 0.0
# The Error:
# 0.2936452513966481
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3466305865921788
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.31267458100558654
# The Error:
# 0.3982192737430168
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3564944134078212
# The Error:
# 0.22782821229050276
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# 100%|██████████| 50/50 [00:52<00:00,  1.04s/it, best loss: 0.22782821229050276]
# Best Loss 0.22782821229050276
# FINAL Error: 0.22782821229050276
# The dataset with random state 1 is used
# The Error:
# 0.35797835195530725
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3809357541899442
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2949546089385475
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.32672835195530725
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.34392458100558654
# The Error:
# 0.2995810055865922
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2981843575418994
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3136347765363129
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.31878491620111726
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2957402234636871
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.28151187150837986
# The Error:
# 0.0
# The Error:
# 0.34916201117318435
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# 100%|██████████| 50/50 [00:50<00:00,  1.01s/it, best loss: 0.25776885474860334]
# Best Loss 0.25776885474860334
# FINAL Error: 0.25776885474860334
# The dataset with random state 602 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2961766759776536
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.35597067039106145
# The Error:
# 0.2948673184357542
# The Error:
# 0.0
# The Error:
# 0.29862081005586594
# The Error:
# 0.0
# The Error:
# 0.25741969273743015
# The Error:
# 0.2948673184357542
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.37517458100558654
# The Error:
# 0.3314420391061452
# The Error:
# 0.0
# The Error:
# 0.291550279329609
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25628491620111726
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.31023044692737434
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3181738826815642
# 100%|██████████| 50/50 [00:49<00:00,  1.00it/s, best loss: 0.25628491620111726]
# Best Loss 0.25628491620111726
# FINAL Error: 0.25628491620111726
# The dataset with random state 295 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.39769553072625696
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.4230097765363129
# The Error:
# 0.42004189944134074
# The Error:
# 0.3626047486033519
# The Error:
# 0.3286487430167597
# The Error:
# 0.3373777932960894
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.30307262569832405
# The Error:
# 0.0
# The Error:
# 0.3293470670391061
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.30665153631284914
# The Error:
# 0.29914455307262566
# The Error:
# 0.2877094972067039
# The Error:
# 0.0
# The Error:
# 0.2936452513966481
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3846892458100558
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3207925977653632
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# 100%|██████████| 50/50 [00:53<00:00,  1.08s/it, best loss: 0.25776885474860334]
# Best Loss 0.25776885474860334
# FINAL Error: 0.25776885474860334
# The dataset with random state 970 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.299231843575419
# The Error:
# 0.3753491620111732
# The Error:
# 0.37037360335195535
# The Error:
# 0.3037709497206704
# The Error:
# 0.29390712290502796
# The Error:
# 0.29268505586592175
# The Error:
# 0.0
# The Error:
# 0.29259776536312854
# The Error:
# 0.29067737430167595
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.29390712290502796
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.29425628491620115
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3496857541899442
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# 100%|██████████| 50/50 [00:50<00:00,  1.01s/it, best loss: 0.29067737430167595]
# Best Loss 0.29067737430167595
# FINAL Error: 0.29067737430167595
# The dataset with random state 2000 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.39525139664804465
# The Error:
# 0.4362779329608939
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2655377094972067
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.26536312849162014
# The Error:
# 0.0
# The Error:
# 0.265625
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.28753491620111726
# The Error:
# 0.25776885474860334
# The Error:
# 0.2929469273743017
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.29102653631284914
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.26579958100558654
# The Error:
# 0.0
# The Error:
# 0.3982192737430168
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.29268505586592175
# The Error:
# 0.3032472067039106
# The Error:
# 0.0
# The Error:
# 0.0
# 100%|██████████| 50/50 [00:51<00:00,  1.02s/it, best loss: 0.25776885474860334]
# Best Loss 0.25776885474860334
# FINAL Error: 0.25776885474860334
# The dataset with random state 3000 is used
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3365048882681564
# The Error:
# 0.3393854748603352
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.4234462290502793
# The Error:
# 0.3436627094972067
# The Error:
# 0.4383729050279329
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.47939944134078216
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3246333798882681
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.45452164804469275
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3564944134078212
# The Error:
# 0.2973987430167597
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# 100%|██████████| 50/50 [00:59<00:00,  1.18s/it, best loss: 0.25776885474860334]
# Best Loss 0.25776885474860334
# FINAL Error: 0.25776885474860334
# The dataset with random state 10000 is used
# The Error:
# 0.35710544692737434
# The Error:
# 0.0
# The Error:
# 0.3052548882681564
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.333449720670391
# The Error:
# 0.0
# The Error:
# 0.29748603351955305
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.294518156424581
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.25776885474860334
# The Error:
# 0.2956529329608939
# The Error:
# 0.292161312849162
# The Error:
# 0.0
# The Error:
# 0.29259776536312854
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2439769553072626
# The Error:
# 0.0
# The Error:
# 0.3529155027932961
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.2956529329608939
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.3088337988826816
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.291288407821229
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# The Error:
# 0.0
# 100%|██████████| 50/50 [00:50<00:00,  1.00s/it, best loss: 0.2439769553072626]
# Best Loss 0.2439769553072626
# FINAL Error: 0.2439769553072626
# ----
# {1: 0.25776885474860334,
#  13: 0.22782821229050276,
#  133: 0.25776885474860334,
#  295: 0.25776885474860334,
#  602: 0.25628491620111726,
#  970: 0.29067737430167595,
#  1337: 0.25776885474860334,
#  2000: 0.25776885474860334,
#  3000: 0.25776885474860334,
#  10000: 0.2439769553072626}
# Mean: 0.2565380586592179
# Max: 0.29067737430167595
# Min: 0.22782821229050276
# Distance to max 0.034139315642458035
# Distance to min: -0.028709846368715153

# %%
#

# space={'eta': hp.loguniform('eta',math.exp(-7) ,1),
#        'max_depth': hp.quniform("max_depth", 2,10,2),
#        'subsample': hp.uniform('subsample', 0.5, 1),
#        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
#        'colsample_bylevel' : hp.uniform('colsample_bylevel', 0.5,1),
#        'min_child_weight' : hp.loguniform('min_child_weight', math.exp(-16),math.exp(5)),
#        'alpha' : hp.choice('alpha', [0,hp.loguniform('a',math.exp(-16),math.exp(2))]),
#        'lambda': hp.choice('lambda',[ 0,hp.loguniform('l',math.exp(-16),math.exp(2))]),
#        'gamma': hp.choice ('gamma', [0,hp.loguniform('g',math.exp(-16),math.exp(2))])
        
        
#     }


# # Regression: 
# def hyperparameter_tuning(space):
#     reg=xgb.XGBRegressor( eta = space['eta'],max_depth = int(space['max_depth']), subsample=space['subsample'],
#                          gamma = space['gamma'],reg_alpha = space['alpha'],reg_lambda = space['lambda'],
#                         #  min_child_weight=space['min_child_weight'],
#                          colsample_bytree=space['colsample_bytree'],
#                          colsample_bylevel = space['colsample_bylevel'])
    
#     evaluation = [( data.X_train, data.y_train), ( data.X_valid, data.y_valid)]
    
#     reg.fit(data.X_train, data.y_train,
#             eval_set=evaluation, eval_metric="rmse",
#             early_stopping_rounds=10,verbose=False)

#     pred = reg.predict(data.X_valid)
#     mse= mean_squared_error(data.y_valid, pred)
#     print ("SCORE:", mse)
#     #change the metric if you like
#     return {'loss':mse, 'status': STATUS_OK }

# %%
# trials = Trials()
# best = fmin(fn=hyperparameter_tuning,
#             space=space,
#             algo=tpe.suggest,
#             max_evals=50,
#             trials=trials)

# print (best)
# Out:
# [16:15:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.6822184
# [16:23:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.6917804
# [16:29:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.69277877
# [16:33:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.6898674
# [16:39:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.6913441
# [16:46:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.68847024
# [16:56:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.7375048
# [16:58:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.6999874
# [17:04:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.69745606
# [17:10:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.68004364
# [17:16:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.6914822
# [17:21:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# SCORE:
# 0.6835112
# [17:29:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#  24%|██▍       | 12/50 [1:18:53<4:09:50, 394.48s/it, best loss: 0.680043637752533]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-f1b7570306ac> in <module>()
#       4             algo=tpe.suggest,
#       5             max_evals=50,
# ----> 6             trials=trials)
#       7
#       8 print (best)
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     386             catch_eval_exceptions=catch_eval_exceptions,
#     387             return_argmin=return_argmin,
# --> 388             show_progressbar=show_progressbar,
#     389         )
#     390
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar)
#     637             catch_eval_exceptions=catch_eval_exceptions,
#     638             return_argmin=return_argmin,
# --> 639             show_progressbar=show_progressbar)
#     640
#     641
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     405                     show_progressbar=show_progressbar)
#     406     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 407     rval.exhaust()
#     408     if return_argmin:
#     409         return trials.argmin
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in exhaust(self)
#     260     def exhaust(self):
#     261         n_done = len(self.trials)
# --> 262         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     263         self.trials.refresh()
#     264         return self
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     225                     else:
#     226                         # -- loop over trials and do the jobs directly
# --> 227                         self.serial_evaluate()
#     228
#     229                     try:
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     139                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     140                 try:
# --> 141                     result = self.domain.evaluate(spec, ctrl)
#     142                 except Exception as e:
#     143                     logger.info('job exception: %s' % str(e))
#
# /usr/local/lib/python3.6/dist-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     842                 memo=memo,
#     843                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 844             rval = self.fn(pyll_rval)
#     845
#     846         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-68-4a77ce3638fa> in hyperparameter_tuning(space)
#      27     reg.fit(data.X_train, data.y_train,
#      28             eval_set=evaluation, eval_metric="rmse",
# ---> 29             early_stopping_rounds=10,verbose=False)
#      30
#      31     pred = reg.predict(data.X_test)
#
# /usr/local/lib/python3.6/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
